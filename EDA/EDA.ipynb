# %%
import pandas as pd          # ✅ Para manejar el DataFrame con los datos de coches
import plotly_express as px  # ✅ Para crear histogramas y gráficos de dispersión
import streamlit as st       # ✅ Para crear la aplicación web
import plotly as pl          
import nbformat as nbf
